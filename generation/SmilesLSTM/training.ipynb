# %%
import warnings
from src import train

warnings.simplefilter("ignore")

train.main(config_filepath="./configs/setting.yaml")
# Out:
# Seed set to 42
# 2024-04-24 13:32:15 | INFO |    OS: Windows
# 2024-04-24 13:32:15 | INFO |    Training Dataset filepath: ./data/zinc.csv
# ...
# 100%|██████████| 79570/79570 [00:00<00:00, 308100.07it/s]
# 2024-04-24 13:32:23 | INFO |    Loading training SMILES data.
# 1511811it [00:07, 194913.02it/s]
# 2024-04-24 13:32:31 | INFO |    Data size: torch.Size([1511811, 104])
# 2024-04-24 13:32:31 | INFO |
# 2024-04-24 13:32:31 | INFO |    Loading validation SMILES data.
# 79570it [00:00, 198765.84it/s]
# 2024-04-24 13:32:31 | INFO |    Data size: torch.Size([79570, 104])
# 2024-04-24 13:32:31 | INFO |
# 2024-04-24 13:32:31 | INFO |    All vocabulary:
# ...
