# %%
import warnings
from smiles_lstm import train

warnings.simplefilter("ignore")

train.main(config_filepath="./configs/setting.yaml")
# Out:
# Seed set to 42
# 2024-04-17 10:05:04 | INFO |    OS: Windows
# 2024-04-17 10:05:04 | INFO |    Training Dataset filepath: ./data/zinc.csv
# 2024-04-17 10:05:04 | INFO |    Loading training SMILES data.
# 100%|██████████| 1511811/1511811 [00:18<00:00, 79985.87it/s]
# 2024-04-17 10:05:29 | INFO |    Data size: torch.Size([1511811, 102])
# 2024-04-17 10:05:29 | INFO |
# 2024-04-17 10:05:29 | INFO |    Loading validation SMILES data.
# 100%|██████████| 79570/79570 [00:00<00:00, 85675.02it/s]
# 2024-04-17 10:05:30 | INFO |    Data size: torch.Size([79570, 102])
# 2024-04-17 10:05:30 | INFO |
# 2024-04-17 10:05:30 | INFO |    All vocabulary:
# 2024-04-17 10:05:30 | INFO |    [' ', '!', '?', '(', ')', '1', '2', '=', 'C', 'F', 'N', 'O', 'c', 'l', 'n', '3', '4', '5', '-', 'S', 'H', '[', ']', 'o', 'B', 'r', '6', '7', '#', 's', '+', 'i', 'I', 'P', 'e', '8', '9', '%', '0', 'p', 'b']
# 2024-04-17 10:05:30 | INFO |    Shows the initial molecular SMILES of the training data.
# ...
