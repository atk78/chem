# %%
from smiles_vae.generate import generate_smiles

generated_smiles = generate_smiles(n_generation=1000, training_dir="./reports/training")
print(generated_smiles)
# Out:
# ['O=C(CCO)Cc1ccc(C(CCI)c2cc(Cl)c[nH]2)c2ccccc12', 'CCOc1ccc(C(C#N)=CC(=O)N2CCCC2)nc1N1CCC(C(=O)O)CC1C', 'CCC(C1CC#CC1)n1c(N)nc2nccnc21', 'C=Cc1ccc(C(O)N2CCCCC2)cc1F', 'CNC(C(=O)NCc1ccccc1)c1ccc(O)c(OCC2OC(C(=O)N(C)S)C(C)CC2C)c1', 'CCn1cc(-c2ccccc2)n2c3ccccc3nc12', 'CCOC(C)n1cc(C(=O)C(NCc2cn(-c3ccccc3)c(=O)n(C)c2=O)c2ccccc2)nc1C', 'CCc1ccc(CC)c2c(OC3OC(C(C)C)C(Cl)C3CC3CCNC3)onc12', 'Cc1c(NC(=O)c2csc(S(=O)(=O)N3CCCC3C(=O)O)c2)ccc2c(-c3ccccc3)nn(C)c(=O)c12', 'COc1cccc(NCC(c2ccccc2)[N+](=O)[Se]C=CC(C)=NS(=O)(=O)c2ccc(Cl)cc2)c1', 'O=Nc1ccc(-c2ccccc2OC2CCOC2)cn1', 'Cc1ccc(OCc2cccc(Cc3ccc(F)cc3)c2)cc1N', 'Cn1cnc(CN2CCC(NCc3cccc(OC=NO)c3)CC2)c1', 'CC(COc1ccc(-c2ccco2)cc1)=Nc1ccc(SC(C)(C)CN)s1', 'O=C(OC(CCN1CCC(O)(C=Cc2ccco2)CC1)c1ccccc1)c1ccc(Cl)cc1', 'CCc1ccn(CCOc2c(NC(=O)CF)ccc(Cl)c2Nc2cccc(C)c2)c1', 'CCc1cccnc1-c1ccc(CC(C)(O)c2cc(Cl)ccc2I)c(O)c1C', 'CCOC(=O)c1cccc(N(C)C(=O)CNC(=N)N(COC)C(=O)OC(F)(F)F)n1', 'O=C(O)Nc1ccccc1Cn1c(F)cc2ccccc21', 'Cc1cc(C#N)c(O)c(NCC2CCCN2)c1C', 'N#CC(Cn1c(-c2c
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Draw

num = 9
display(Draw.MolToImage(Chem.MolFromSmiles(generated_smiles[num])))
print(len(generated_smiles))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 1000
