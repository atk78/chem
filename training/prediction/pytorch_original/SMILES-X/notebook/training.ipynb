# %%
import os
import sys
sys.path.append("./../")
from src import train

data_name = "FreeSolv"
config_filepath = os.path.join("../configs", f"{data_name}.yaml")

train.run(config_filepath)
# Out:
# shape: (5, 2)
# ┌────────────────────────┬────────┐
# │ smiles                 ┆ expt   │
# │ ---                    ┆ ---    │
# │ str                    ┆ f64    │
# ╞════════════════════════╪════════╡
# │ COc1ccc(C(=O)N(C)C)cc1 ┆ -11.01 │
# │ CS(=O)(=O)Cl           ┆ -4.87  │
# │ C=CC(C)C               ┆ 1.83   │
# │ CCc1cnccn1             ┆ -5.45  │
# │ CCCCCCCO               ┆ -4.21  │
# └────────────────────────┴────────┘
# 2024-11-20 21:29:57 | INFO |    OS: Windows
# 2024-11-20 21:29:57 | INFO |    precision is 16
# 2024-11-20 21:29:57 | INFO |    ***Sampling and splitting of the dataset.***
# 2024-11-20 21:29:58 | INFO |    Setup Molecule Tokens.
# 2024-11-20 21:29:58 | INFO |    ***Data augmentation is True.***
# 2024-11-20 21:29:58 | INFO |    Augmented SMILES data size:
# 2024-11-20 21:29:58 | INFO |    Tokens:
# ...
