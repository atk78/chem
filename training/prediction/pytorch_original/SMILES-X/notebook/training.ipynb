# %%
import os
import sys
sys.path.append("./../")
from src import train

data_name = "FreeSolv"
config_filepath = os.path.join("../configs", f"{data_name}.yaml")

train.run(config_filepath)
# Out:
# shape: (5, 2)
# ┌────────────────────────┬────────┐
# │ smiles                 ┆ expt   │
# │ ---                    ┆ ---    │
# │ str                    ┆ f64    │
# ╞════════════════════════╪════════╡
# │ COc1ccc(C(=O)N(C)C)cc1 ┆ -11.01 │
# │ CS(=O)(=O)Cl           ┆ -4.87  │
# │ C=CC(C)C               ┆ 1.83   │
# │ CCc1cnccn1             ┆ -5.45  │
# │ CCCCCCCO               ┆ -4.21  │
# └────────────────────────┴────────┘
# 2024-10-28 11:28:59 | INFO |    OS: Windows
# 2024-10-28 11:28:59 | INFO |    precision is 16
# 2024-10-28 11:28:59 | INFO |    ***Sampling and splitting of the dataset.***
# 2024-10-28 11:28:59 | INFO |    Setup Molecule Tokens.
# 2024-10-28 11:28:59 | INFO |    Tokens:
# 2024-10-28 11:28:59 | INFO |    [')', 'O', '=', 'c', '4', ' ', 'F', '1', '[C@@H]', 'N', '(', '[O-]', 'I', '[C@]', 's', '#', '2', 'P', '3', 'S', 'n', '[N+]', '\\', '/', '[C@H]', '[nH]', 'C', '5', 'Cl', 'Br', '-', '[S+2]', '[C@@]']
# ...
