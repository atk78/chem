# %%
from pathlib import Path

import pandas as pd
from rdkit import Chem

permitted_atomes = ["C", "N", "O", "S", "F", "Cl", "Br", "I"] + ["*"]
permitted_atomes_set = set(permitted_atomes)

file_path = Path("./../../../../data/FreeSolv.csv")
prop = "expt"

df = pd.read_csv(file_path)
df = df[["smiles", prop]]
display(df.head())
print("前処理前のサンプル数:", len(df))
def check_atoms(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        atoms_set = set([atom.GetSymbol() for atom in mol.GetAtoms()])
        isin = permitted_atomes_set > atoms_set
        if isin:
            return smiles
        else:
            return None
    except:
        return None

df["smiles"] = df["smiles"].map(check_atoms)
df = df.dropna().reset_index(drop=True)
df.to_csv("./../data/FreeSolv.csv", index=False)
print("前処理後のサンプル数:", len(df))
df
# Out:
#                    smiles   expt
# 0  COc1ccc(C(=O)N(C)C)cc1 -11.01
# 1            CS(=O)(=O)Cl  -4.87
# 2                C=CC(C)C   1.83
# 3              CCc1cnccn1  -5.45
# 4                CCCCCCCO  -4.21
# 前処理前のサンプル数: 642
# 前処理後のサンプル数: 628
#                      smiles   expt
# 0    COc1ccc(C(=O)N(C)C)cc1 -11.01
# 1              CS(=O)(=O)Cl  -4.87
# 2                  C=CC(C)C   1.83
# 3                CCc1cnccn1  -5.45
# 4                  CCCCCCCO  -4.21
# ..                      ...    ...
# 623          CCCCCCCC(=O)OC  -2.04
# 624                 C1CCNC1  -5.48
# 625          O=Cc1ccc(O)cc1  -8.83
# 626               CCCCCCCCl   0.29
# 627                C1COCCO1  -5.06
#
# [628 rows x 2 columns]
