# %%
import os

from src import train

data_name = "FreeSolv2"
config_filepath = os.path.join("configs", f"{data_name}.yaml")

train.run(
    config_filepath,
    outdir="./reports/",
    n_gpus=1,
)
# Out:
#                    smiles   expt
# 0  COc1ccc(C(=O)N(C)C)cc1 -11.01
# 1            CS(=O)(=O)Cl  -4.87
# 2                C=CC(C)C   1.83
# 3              CCc1cnccn1  -5.45
# 4                CCCCCCCO  -4.21
# 2024-04-12 23:09:36 | INFO |    OS: Windows
# Seed set to 42
# 2024-04-12 23:09:36 | INFO |    precision is 32
# 2024-04-12 23:09:36 | INFO |    ***Sampling and splitting of the dataset.***
# 2024-04-12 23:09:36 | INFO |    Train/valid/test splits:0.80/0.10/0.10
# 2024-04-12 23:09:36 | INFO |    Setup Molecule Tokens.
# 2024-04-12 23:09:36 | INFO |    ***Data augmentation is True.***
# 2024-04-12 23:09:36 | INFO |    Augmented selfies data size:
# 2024-04-12 23:09:37 | INFO |    	Training set   | 4345
# 2024-04-12 23:09:37 | INFO |    	Validation set | 517
# 2024-04-12 23:09:37 | INFO |    	Test set       | 493
# 2024-04-12 23:09:37 | INFO |    Number of tokens only present in a training set: 42
# ...
