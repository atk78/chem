# %%
import pandas as pd
from rdkit import Chem

permitted_atomes = ["B", "C", "N", "O", "S", "P", "F", "Cl", "Br", "I"] + ["*"]
permitted_atomes_set = set(permitted_atomes)

file_path = "data/raw/Density.csv"
prop = "density"

df = pd.read_csv(file_path)
df = df[["smiles", prop]]
print("前処理前のサンプル数:", len(df))
def check_atoms(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        atoms_set = set([atom.GetSymbol() for atom in mol.GetAtoms()])
        isin = permitted_atomes_set > atoms_set
        if isin:
            return smiles
        else:
            return None
    except:
        return None

df["smiles"] = df["smiles"].map(check_atoms)
df = df.dropna().reset_index(drop=True)
df.to_csv("data/processed/Density.csv", index=False)
print("前処理後のサンプル数:", len(df))
df
# Out:
# 前処理前のサンプル数: 1694
# 前処理後のサンプル数: 1625
#                                                  smiles  density
# 0                                                  *CC*   0.9362
# 1                                               *CC(*)C   0.9031
# 2                                              *CC(*)CC   0.9000
# 3                                             *CC(*)CCC   0.9000
# 4                                           *CC(*)C(C)C   0.9060
# ...                                                 ...      ...
# 1620                           *CC(*)(F)C(=O)OCC(F)(F)F   1.5868
# 1621                    *CC(*)(F)C(=O)OCC(F)(F)C(F)(F)F   1.6540
# 1622                       *CC(*)(F)C(=O)OCC(F)(F)C(F)F   1.6447
# 1623         *CC(*)(F)C(=O)OCC(F)(F)C(F)(F)C(F)(F)C(F)F   1.7588
# 1624  *CC(*)(F)C(=O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C...   1.8192
#
# [1625 rows x 2 columns]
