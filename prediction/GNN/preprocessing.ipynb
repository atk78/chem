# %%
import pandas as pd
from rdkit import Chem

permitted_atomes = ["B", "C", "N", "O", "S", "P", "F", "Cl", "Br", "I"] + ["*"]
permitted_atomes_set = set(permitted_atomes)

file_path = "data/raw/Tg.csv"
prop = "tg"

df = pd.read_csv(file_path)
df = df[["smiles", prop]]
print("前処理前のサンプル数:", len(df))
def check_atoms(smiles):
    try:
        mol = Chem.MolFromSmiles(smiles)
        atoms_set = set([atom.GetSymbol() for atom in mol.GetAtoms()])
        isin = permitted_atomes_set > atoms_set
        if isin:
            return smiles
        else:
            return None
    except:
        return None

# def poly_bond_check(smiles):
#     poly_bond_num = smiles.count("*")
#     if poly_bond_num == 2:
#         return smiles
#     else:
#         return None

df["smiles"] = df["smiles"].map(check_atoms)
df = df.dropna().reset_index(drop=True)
df.to_csv("data/processed/Tg.csv", index=False)
print("前処理後のサンプル数:", len(df))
df
# Out:
# 前処理前のサンプル数: 7175
# 前処理後のサンプル数: 6696
#                                              smiles     tg
# 0                                               *C* -120.0
# 1                                              *CC* -120.0
# 2                                           *CC(*)C   -3.0
# 3                                          *CC(*)CC  -24.1
# 4                                         *CC(*)CCC  -37.0
# ...                                             ...    ...
# 6691                             *CC(*)(F)C(=O)OCCC   62.0
# 6692        *CC(F)(F)C1(F)C(*)CC(O)(C(F)(F)F)C1(F)F  152.0
# 6693  *CC(F)(F)C1(F)CC(CC(O)(C(F)(F)F)C(F)(F)F)CC1*   98.0
# 6694   *CC(F)(F)C1(F)CC(C(O)(C(F)(F)F)C(F)(F)F)CC1*  118.0
# 6695                    *CC(*)(F)C(=O)OCC(Cl)(Cl)Cl  127.0
#
# [6696 rows x 2 columns]
